# %%
import numpy as np
#m=[t1,t2,t3,t4]
p=np.array([[78,56,81,99],[43,7,23,50],[100,150,92,78],[24,96,84,70],[100,50,25,75]])
c=np.array([[10,70,80,60]])
n_a=np.concatenate((p,c))
print(n_a)
total=[]
for i in n_a:
    total.append(sum(i))
t=np.array(total).reshape(6,1)
n_a1=np.concatenate((n_a,t),axis=1)
print(n_a1)
# Out:
# [[ 78  56  81  99]
#  [ 43   7  23  50]
#  [100 150  92  78]
#  [ 24  96  84  70]
#  [100  50  25  75]
#  [ 10  70  80  60]]
# [[ 78  56  81  99 314]
#  [ 43   7  23  50 123]
#  [100 150  92  78 420]
#  [ 24  96  84  70 274]
#  [100  50  25  75 250]
#  [ 10  70  80  60 220]]

# %%
import numpy as np
import matplotlib.pyplot as plt
sels_data=np.array([[35, 45, 60, 20, 40], [50, 40, 35, 30, 25], [25, 55, 50, 15, 35], [60, 30, 40, 50, 20], [45, 35, 55, 25, 30], [30, 50, 45, 40, 50]])
stationery_sales =np.array([25, 30, 20, 35, 40, 45])
t=np.array((stationery_sales).reshape(6,1))
nal=np.concatenate((sels_data,t),axis=1)
print(nal)
print("add emp_7")
Employee_7 =np.array([[40, 50, 30, 20, 60, 35]])
ab=np.concatenate((nal,Employee_7))
print(ab)
y=ab[:,2]
emp=np.array(['Employee_1','Employee_2','Employee_3','Employee_4','Employee_5','Employee_6','Employee_7'])
plt.plot(emp,y)
plt.xlabel('Employee-->',fontsize=15,color='gray')
plt.ylabel('sales fation-->',fontsize=15,color='gray')
plt.title("sales management",color='black')
plt.show()
y=ab[:,1]
plt.scatter(emp,y)
plt.xlabel('Employee-->',fontsize=15,color='gray')
plt.ylabel('electronics-->',fontsize=15,color='gray')
plt.title("employee * electronics",color='black')
aa=['Groceries','Electronics','Fashion','Furniture','Books','stationary']
emp3=np.array([25, 55, 50, 15, 35, 20])
plt.show()
plt.bar(aa,emp3)
plt.xlabel('Employee3 all items-->',fontsize=15,color='gray')
plt.ylabel('all sels count-->',fontsize=15,color='gray')
plt.title("employee3 * all item",color='black')
plt.show()
aa=['Groceries','Electronics','Fashion','Furniture','Books','stationary']
emp6=np.array([30, 50, 45, 40, 50, 45])
plt.barh(aa,emp6)
plt.ylabel('Employee6 all items-->',fontsize=15,color='gray')
plt.xlabel('all sels count-->',fontsize=15,color='gray')
plt.title("employee6 * all item",color='black')
plt.show()


aa=['Groceries','Electronics','Fashion','Furniture','Books','stationary']
emp4=[60, 30, 40, 50, 20, 35]
plt.figure(figsize=(8,8))
plt.pie(emp4,labels=aa,explode=[0.2,0,0,0,0,0],autopct='%0.1f%%')
plt.legend(loc='upper left')
plt.show()
# Out:
# [[35 45 60 20 40 25]
#  [50 40 35 30 25 30]
#  [25 55 50 15 35 20]
#  [60 30 40 50 20 35]
#  [45 35 55 25 30 40]
#  [30 50 45 40 50 45]]
# add emp_7
# [[35 45 60 20 40 25]
#  [50 40 35 30 25 30]
#  [25 55 50 15 35 20]
#  [60 30 40 50 20 35]
#  [45 35 55 25 30 40]
#  [30 50 45 40 50 45]
#  [40 50 30 20 60 35]]
